# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Uploading and Displaying Data

netflix_df = pd.read_excel('mymoviedb.xlsx')
netflix_df
# Out:
#              Release_Date                                 Title  \
# 0     2021-12-15 00:00:00               Spider-Man: No Way Home
# 1     2022-03-01 00:00:00                            The Batman
# 2     2022-02-25 00:00:00                               No Exit
# 3     2021-11-24 00:00:00                               Encanto
# 4     2021-12-22 00:00:00                        The King's Man
# ...                   ...                                   ...
# 9832  1973-10-15 00:00:00                              Badlands
# 9833  2020-10-01 00:00:00                      Violent Delights
# 9834  2016-05-06 00:00:00                          The Offering
# 9835  2021-03-31 00:00:00  The United States vs. Billie Holiday
# 9836  1984-09-23 00:00:00                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# ...

# %%
#Sample Data From Top

netflix_df.head(10)
# Out:
#           Release_Date                    Title  \
# 0  2021-12-15 00:00:00  Spider-Man: No Way Home
# 1  2022-03-01 00:00:00               The Batman
# 2  2022-02-25 00:00:00                  No Exit
# 3  2021-11-24 00:00:00                  Encanto
# 4  2021-12-22 00:00:00           The King's Man
# 5  2022-01-07 00:00:00             The Commando
# 6  2022-01-12 00:00:00                   Scream
# 7  2022-02-10 00:00:00                     Kimi
# 8  2022-02-17 00:00:00     Fistful of Vengeance
# 9  2021-11-03 00:00:00                 Eternals
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
# 1  In his second year of fighting crime, Batman u...    3827.658       1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087        122
# 3  The tale of an extraordinary family, the Madri...    2402.201       5076
# ...

# %%
#Sample Data From Bottom

netflix_df.tail(10)
# Out:
#              Release_Date                                 Title  \
# 9827  2005-05-18 00:00:00     I'm in Love With My Little Sister
# 9828  2013-08-23 00:00:00                           All Is Lost
# 9829  2008-05-13 00:00:00            Amateur Porn Star Killer 2
# 9830  1992-06-26 00:00:00                        Unlawful Entry
# 9831  1974-11-06 00:00:00                     The Little Prince
# 9832  1973-10-15 00:00:00                              Badlands
# 9833  2020-10-01 00:00:00                      Violent Delights
# 9834  2016-05-06 00:00:00                          The Offering
# 9835  2021-03-31 00:00:00  The United States vs. Billie Holiday
# 9836  1984-09-23 00:00:00                               Threads
#
#                                                Overview  Popularity  \
# 9827  Yori and his twin sister Iku used to be very c...      13.360
# 9828  During a solo voyage in the Indian Ocean, a ve...      13.359
# ...

# %%
#Shape Of Data

netflix_df.shape
# Out:
# (9837, 9)

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9837 non-null   object
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 691.8+ KB

# %%
netflix_df.describe()
# Out:
#         Popularity
# count  9827.000000
# mean     40.320570
# std     108.874308
# min       7.100000
# 25%      16.127500
# 50%      21.191000
# 75%      35.174500
# max    5083.954000

# %%
#Checking NULL Values

netflix_df.isnull().sum()
# Out:
# Release_Date          0
# Title                 9
# Overview              9
# Popularity           10
# Vote_Count           10
# Vote_Average         10
# Original_Language    10
# Genre                11
# Poster_Url           11
# dtype: int64

# %%
#Delete NULL Values

netflix_df.dropna(inplace=True)

# %%
netflix_df.isnull().sum()
# Out:
# Release_Date         0
# Title                0
# Overview             0
# Popularity           0
# Vote_Count           0
# Vote_Average         0
# Original_Language    0
# Genre                0
# Poster_Url           0
# dtype: int64

# %%
#Data Types 

netflix_df.dtypes
# Out:
# Release_Date          object
# Title                 object
# Overview              object
# Popularity           float64
# Vote_Count            object
# Vote_Average          object
# Original_Language     object
# Genre                 object
# Poster_Url            object
# dtype: object

# %%
#Changing Data Types

netflix_df['Vote_Count'] = netflix_df['Vote_Count'].astype(int)
netflix_df['Vote_Average'] = netflix_df['Vote_Average'].astype(float)
netflix_df['Release_Date'] = pd.to_datetime(netflix_df['Release_Date'])

# %%
#Descripton of Data

netflix_df.describe()
# Out:
#                         Release_Date   Popularity    Vote_Count  Vote_Average
# count                           9826  9826.000000   9826.000000   9826.000000
# mean   2006-09-23 04:47:14.276409600    40.323951   1392.943721      6.439467
# min              1902-04-17 00:00:00    13.354000      0.000000      0.000000
# 25%              2000-10-17 12:00:00    16.128250    146.000000      5.900000
# 50%              2011-09-12 00:00:00    21.195000    444.000000      6.500000
# 75%              2017-11-22 00:00:00    35.179250   1376.000000      7.100000
# max              2024-07-03 00:00:00  5083.954000  31077.000000     10.000000
# std                              NaN   108.879332   2611.303856      1.129797

# %%
#Information of Data

netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9826 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9826 non-null   datetime64[ns]
#  1   Title              9826 non-null   object
#  2   Overview           9826 non-null   object
#  3   Popularity         9826 non-null   float64
#  4   Vote_Count         9826 non-null   int32
#  5   Vote_Average       9826 non-null   float64
#  6   Original_Language  9826 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: datetime64[ns](1), float64(2), int32(1), object(5)
# memory usage: 729.3+ KB

# %%
#Changing Date to Year Format

netflix_df['Release_Date'] = netflix_df['Release_Date'].dt.year
netflix_df['Release_Date'].dtypes
# Out:
# dtype('int32')

# %%
col = ['Overview', 'Original_Language', 'Poster_Url']

# %%
#Deleting unwanted Columns

netflix_df.drop(col, axis=1, inplace=True)

netflix_df.columns
# Out:
# Index(['Release_Date', 'Title', 'Popularity', 'Vote_Count', 'Vote_Average',
#        'Genre'],
#       dtype='object')

# %%
netflix_df.head(10)
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2022               The Batman    3827.658        1151
# 2          2022                  No Exit    2618.087         122
# 3          2021                  Encanto    2402.201        5076
# 4          2021           The King's Man    1895.511        1793
# 5          2022             The Commando    1750.484          33
# 6          2022                   Scream    1675.161         821
# 7          2022                     Kimi    1601.782         206
# 8          2022     Fistful of Vengeance    1594.013         114
# 9          2021                 Eternals    1537.406        4726
#
#    Vote_Average                               Genre
# 0           8.3  Action, Adventure, Science Fiction
# 1           8.1            Crime, Mystery, Thriller
# 2           6.3                            Thriller
# ...

# %%
def categorize_col(netflix_df, col, labels):

    edges = [netflix_df[col].describe()['min'],
            netflix_df[col].describe()['25%'],
            netflix_df[col].describe()['50%'],
            netflix_df[col].describe()['75%'],
            netflix_df[col].describe()['max']]
    netflix_df[col] = pd.cut(netflix_df[col], edges, labels=labels, duplicates='drop')
    return netflix_df

# %%
labels = ['Not Popular', 'Below Average', 'Average', 'Popular']
categorize_col(netflix_df, 'Vote_Average', labels)

netflix_df['Vote_Average'].unique()
# Out:
# ['Popular', 'Below Average', 'Average', 'Not Popular', NaN]
# Categories (4, object): ['Not Popular' < 'Below Average' < 'Average' < 'Popular']

# %%
netflix_df.head(10)
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2022               The Batman    3827.658        1151
# 2          2022                  No Exit    2618.087         122
# 3          2021                  Encanto    2402.201        5076
# 4          2021           The King's Man    1895.511        1793
# 5          2022             The Commando    1750.484          33
# 6          2022                   Scream    1675.161         821
# 7          2022                     Kimi    1601.782         206
# 8          2022     Fistful of Vengeance    1594.013         114
# 9          2021                 Eternals    1537.406        4726
#
#     Vote_Average                               Genre
# 0        Popular  Action, Adventure, Science Fiction
# 1        Popular            Crime, Mystery, Thriller
# 2  Below Average                            Thriller
# ...

# %%
netflix_df['Vote_Average'].value_counts()
# Out:
# Vote_Average
# Not Popular      2467
# Popular          2450
# Average          2411
# Below Average    2398
# Name: count, dtype: int64

# %%
netflix_df.isna().sum()
# Out:
# Release_Date      0
# Title             0
# Popularity        0
# Vote_Count        0
# Vote_Average    100
# Genre             0
# dtype: int64

# %%
netflix_df.dropna(inplace=True)
netflix_df.isna().sum()
# Out:
# Release_Date    0
# Title           0
# Popularity      0
# Vote_Count      0
# Vote_Average    0
# Genre           0
# dtype: int64

# %%
netflix_df['Genre'] = netflix_df['Genre'].str.split(', ')
netflix_df = netflix_df.explode('Genre').reset_index(drop=True)
netflix_df.head(10)
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940
# 1          2021  Spider-Man: No Way Home    5083.954        8940
# 2          2021  Spider-Man: No Way Home    5083.954        8940
# 3          2022               The Batman    3827.658        1151
# 4          2022               The Batman    3827.658        1151
# 5          2022               The Batman    3827.658        1151
# 6          2022                  No Exit    2618.087         122
# 7          2021                  Encanto    2402.201        5076
# 8          2021                  Encanto    2402.201        5076
# 9          2021                  Encanto    2402.201        5076
#
#     Vote_Average            Genre
# 0        Popular           Action
# 1        Popular        Adventure
# 2        Popular  Science Fiction
# 3        Popular            Crime
# 4        Popular          Mystery
# 5        Popular         Thriller
# ...

# %%
netflix_df['Genre'] = netflix_df['Genre'].astype('category')
netflix_df['Genre'].dtypes
# Out:
# CategoricalDtype(categories=['Action', 'Adventure', 'Animation', 'Comedy', 'Crime',
#                   'Documentary', 'Drama', 'Family', 'Fantasy', 'History',
#                   'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction',
#                   'TV Movie', 'Thriller', 'War', 'Western'],
# , ordered=False, categories_dtype=object)

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25551 entries, 0 to 25550
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Release_Date  25551 non-null  int32
#  1   Title         25551 non-null  object
#  2   Popularity    25551 non-null  float64
#  3   Vote_Count    25551 non-null  int32
#  4   Vote_Average  25551 non-null  category
#  5   Genre         25551 non-null  category
# dtypes: category(2), float64(1), int32(2), object(1)
# memory usage: 649.8+ KB

# %%
sns.set_style('whitegrid')

# %%
#Gnere Column Distribution

ax = sns.catplot(data=netflix_df, y='Genre', kind='count', order=netflix_df['Genre'].value_counts().index)

plt.title('Gnere Column Distribution');
plt.tight_layout()
plt.show()

# %% [markdown]
# **The majority of Netflix content falls under the Drama and Comedy genres, indicating these are the most popular categories on the platform. Genres such as Documentary and Western have the least representation, reflecting a much smaller audience or production focus for these types of content on Netflix.**

# %%
#Vote Column Distribution

ax = sns.catplot(data=netflix_df, y='Vote_Average', kind='count', order=netflix_df['Vote_Average'].value_counts().index)

plt.title('Vote Distribution');
plt.tight_layout()
plt.show()

# %% [markdown]
# **The vote distribution for Netflix content is relatively balanced across all categories, with no single group significantly outweighing the others. This suggests a diverse range of viewer opinions, indicating that titles appeal to different audience segments with varying popularity and ratings.**

# %%
#Finding Highest Popularity Film and its Gnere

netflix_df[netflix_df['Popularity'] == netflix_df['Popularity'].max()]
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954        8940      Popular
# 1          2021  Spider-Man: No Way Home    5083.954        8940      Popular
# 2          2021  Spider-Man: No Way Home    5083.954        8940      Popular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction

# %%
#Finding lowest Popularity Film and its Gnere

netflix_df[netflix_df['Popularity'] == netflix_df['Popularity'].min()]
# Out:
#        Release_Date                                 Title  Popularity  \
# 25545          2021  The United States vs. Billie Holiday      13.354
# 25546          2021  The United States vs. Billie Holiday      13.354
# 25547          2021  The United States vs. Billie Holiday      13.354
# 25548          1984                               Threads      13.354
# 25549          1984                               Threads      13.354
# 25550          1984                               Threads      13.354
#
#        Vote_Count Vote_Average            Genre
# 25545         152      Average            Music
# 25546         152      Average            Drama
# 25547         152      Average          History
# 25548         186      Popular              War
# 25549         186      Popular            Drama
# 25550         186      Popular  Science Fiction

# %%
#Release Date Column Distribution

netflix_df['Release_Date'].hist()
plt.title('Release Date Column Distribution')
plt.show()

# %% [markdown]
# **Most Netflix content has been released in the last two decades, with a dramatic surge after 2010. This reflects Netflix's rapid expansion and increasing investment in original programming and acquisitions in recent years.**

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **Based on the three graphs, Netflix's content catalog is notably diverse with a strong focus on Drama and Comedy genres, reflecting popular viewer preferences. The platform has experienced significant growth in content production, especially after 2010, coinciding with the surge in subscriber base and revenue. The vote distribution shows a balanced popularity among titles, indicating varied viewer engagement across different content. Together, these trends highlight Netflix's successful expansion strategy through extensive content variety and increasing investment in new releases, fueling its continued market dominance.**
